# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkabirla19/Bank-Fraud-Detection/blob/main/Major_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv("bank_dataset.csv.csv", encoding='unicode_escape')
df
# Out:
#        Unnamed: 0  label       msisdn  aon daily_decr30 daily_decr90  \
# 0               1      0  21408I70789  272      3055.05      3065.15
# 1               2      1  76462I70374  712        12122     12124.75
# 2               3      1  17943I70372  535         1398         1398
# 3               4      1  55773I70781  241       21.228       21.228
# 4               5      1  03813I82730  947  150.6193333  150.6193333
# ...           ...    ...          ...  ...          ...          ...
# 28359       28360      1  04433I70374  724     3267.578      3312.63
# 28360       28361      1  47687I84454  898  33.38866667  33.38866667
# 28361       28362      1  73969I89239  313  2515.766667      2534.15
# 28362       28363      1  23373I70371  736        30.38        30.38
# 28363       28364      1  32183I90847  809    23721.972     23749.84
#
#        rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28364 entries, 0 to 28363
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            28364 non-null  int64
#  1   label                 28364 non-null  int64
#  2   msisdn                28364 non-null  object
#  3   aon                   28364 non-null  object
#  4   daily_decr30          28364 non-null  object
#  5   daily_decr90          28364 non-null  object
#  6   rental30              28364 non-null  object
#  7   rental90              28364 non-null  object
#  8   last_rech_date_ma     28364 non-null  float64
#  9   last_rech_date_da     28364 non-null  float64
#  10  last_rech_amt_ma      28363 non-null  float64
#  11  cnt_ma_rech30         28363 non-null  float64
#  12  fr_ma_rech30          28363 non-null  float64
#  13  sumamnt_ma_rech30     28363 non-null  float64
# ...

# %% [markdown]
# info command gives the information of dataset, it helps to visualize data easily and to get information

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn  aon daily_decr30 daily_decr90 rental30  \
# 0           1      0  21408I70789  272      3055.05      3065.15   220.13
# 1           2      1  76462I70374  712        12122     12124.75  3691.26
# 2           3      1  17943I70372  535         1398         1398   900.13
# 3           4      1  55773I70781  241       21.228       21.228   159.42
# 4           5      1  03813I82730  947  150.6193333  150.6193333   1098.9
#
#   rental90  last_rech_date_ma  last_rech_date_da  ...  maxamnt_loans30  \
# 0   260.13                2.0                0.0  ...              6.0
# 1  3691.26               20.0                0.0  ...             12.0
# 2   900.13                3.0                0.0  ...              6.0
# 3   159.42               41.0                0.0  ...              6.0
# 4   1098.9                4.0                0.0  ...              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# ...

# %% [markdown]
# df.head() gives first 5 rows from dataset

# %%
df=df.drop(['Unnamed: 0'], axis=1)

# %%
df.describe()
# Out:
#               label  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# count  28364.000000       28364.000000        28364.00000      28363.000000
# mean       0.875088        3818.812059         3562.48811       2076.050629
# std        0.330625       54246.262997        53217.32369       2409.270837
# min        0.000000         -29.000000          -27.00000          0.000000
# 25%        1.000000           1.000000            0.00000        770.000000
# 50%        1.000000           3.000000            0.00000       1539.000000
# 75%        1.000000           7.000000            0.00000       2309.000000
# max        1.000000      995749.962400       995848.99970      55000.000000
#
#        cnt_ma_rech30   fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# count   28363.000000   28363.000000       28363.000000          28363.000000
# mean        3.979762    3578.008856        7773.577901           1818.446779
# ...

# %% [markdown]
# this command gives the description of dataset

# %%
df.corr()
# Out:
#                          label  last_rech_date_ma  last_rech_date_da  \
# label                 1.000000           0.007183           0.005552
# last_rech_date_ma     0.007183           1.000000           0.002410
# last_rech_date_da     0.005552           0.002410           1.000000
# last_rech_amt_ma      0.126531          -0.004972          -0.006037
# cnt_ma_rech30         0.237097           0.000616          -0.001954
# fr_ma_rech30          0.011116          -0.004779          -0.004550
# sumamnt_ma_rech30     0.182113          -0.005658          -0.006105
# medianamnt_ma_rech30  0.133370          -0.012969           0.000877
# medianmarechprebal30 -0.006035           0.015196           0.002190
# cnt_ma_rech90         0.232040           0.003759          -0.004893
# fr_ma_rech90          0.091066           0.000636          -0.000202
# sumamnt_ma_rech90     0.192229          -0.002969          -0.008425
# medianamnt_ma_rech90  0.113073          -0.011277          -0.004828
# ...

# %% [markdown]
# this gives corelation between all the columns

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr())

# %% [markdown]
# It plots the heatmap with respect to the correaltion of the dataset.

# %%
df.corr()['label']
# Out:
# label                   1.000000
# last_rech_date_ma       0.007183
# last_rech_date_da       0.005552
# last_rech_amt_ma        0.126531
# cnt_ma_rech30           0.237097
# fr_ma_rech30            0.011116
# sumamnt_ma_rech30       0.182113
# medianamnt_ma_rech30    0.133370
# medianmarechprebal30   -0.006035
# cnt_ma_rech90           0.232040
# fr_ma_rech90            0.091066
# sumamnt_ma_rech90       0.192229
# medianamnt_ma_rech90    0.113073
# medianmarechprebal90    0.024986
# cnt_da_rech30           0.010052
# fr_da_rech30           -0.002169
# cnt_da_rech90          -0.000522
# fr_da_rech90           -0.011208
# cnt_loans30             0.193732
# amnt_loans30            0.193465
# maxamnt_loans30         0.001235
# medianamnt_loans30      0.048082
# cnt_loans90             0.000634
# amnt_loans90            0.195362
# maxamnt_loans90         0.080740
# medianamnt_loans90      0.038803
# payback30               0.045088
# payback90               0.047423
# ...

# %%
cor_matrix = df.corr().abs()

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.80)]

# %%
print(df[to_drop])
# Out:
#        cnt_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  amnt_loans30  \
# 0                2.0             3078.0                1539.0          12.0
# 1                1.0             5787.0                5787.0          12.0
# 2                1.0             1539.0                1539.0           6.0
# 3                1.0              947.0                 947.0          12.0
# 4                8.0            23496.0                2888.0          42.0
# ...              ...                ...                   ...           ...
# 28359            3.0             8765.0                3178.0          12.0
# 28360            1.0             1539.0                1539.0          12.0
# 28361            4.0             7803.0                1543.0          18.0
# 28362            3.0             2319.0                 773.0          18.0
# 28363            NaN                NaN                   NaN           NaN
#
#        amnt_loans90  medianamnt_loans90  payback90
# ...

# %%
df1 = df.drop(df[to_drop], axis=1)

# %%
df1
# Out:
#        label       msisdn  aon daily_decr30 daily_decr90  rental30  rental90  \
# 0          0  21408I70789  272      3055.05      3065.15    220.13    260.13
# 1          1  76462I70374  712        12122     12124.75   3691.26   3691.26
# 2          1  17943I70372  535         1398         1398    900.13    900.13
# 3          1  55773I70781  241       21.228       21.228    159.42    159.42
# 4          1  03813I82730  947  150.6193333  150.6193333    1098.9    1098.9
# ...      ...          ...  ...          ...          ...       ...       ...
# 28359      1  04433I70374  724     3267.578      3312.63   9391.79  12505.07
# 28360      1  47687I84454  898  33.38866667  33.38866667     311.3     311.3
# 28361      1  73969I89239  313  2515.766667      2534.15   2995.78   3045.78
# 28362      1  23373I70371  736        30.38        30.38    215.46    215.46
# 28363      1  32183I90847  809    23721.972     23749.84  10702.12  11598.52
#
# ...

# %%
df['pcircle'].value_counts()
# Out:
# UPW    28363
# Name: pcircle, dtype: int64

# %%
df1=df1.drop(['pcircle'],axis=1)

# %%
df1=df1.drop(['pdate'],axis=1)

# %%
df1=df1.drop(['msisdn'],axis=1)

# %%
df1=df1.drop(['daily_decr90'],axis=1)

# %%
df1=df1.drop(['daily_decr30'],axis=1)

# %%
df1=df1.drop(['rental90'],axis=1)

# %%
df1=df1.drop(['rental30'],axis=1)

# %%
df1=df1.drop(['aon'],axis=1)

# %%
df1.head()
# Out:
#    label  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0      0                2.0                0.0            1539.0
# 1      1               20.0                0.0            5787.0
# 2      1                3.0                0.0            1539.0
# 3      1               41.0                0.0             947.0
# 4      1                4.0                0.0            2309.0
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0            2.0          21.0             3078.0                1539.0
# 1            1.0           0.0             5787.0                5787.0
# 2            1.0           0.0             1539.0                1539.0
# 3            0.0           0.0                0.0                   0.0
# 4            7.0           2.0            20029.0                2309.0
#
#    medianmarechprebal30  fr_ma_rech90  ...  cnt_da_rech30  fr_da_rech30  \
# ...

# %% [markdown]
# # Test and train split

# %%
y = df1["label"]
X = df1.drop("label", axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

D_tree = DecisionTreeClassifier(criterion="entropy")

D_tree.fit(X_train, y_train)

y_pred = D_tree.predict(X_test)

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

confusion_matrix(y_test, y_pred, labels = [0, 1])

# %%
accuracy_score(y_test, y_pred)

# %%
precision_score(y_test, y_pred)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 50,criterion = "entropy")

rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8699382784963557

# %%
precision_score(y_test, y_pred)
# Out:
# 0.8861546603162003
